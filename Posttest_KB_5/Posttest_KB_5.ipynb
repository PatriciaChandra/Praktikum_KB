# %% [markdown]
# ## POSTTEST KB 5

# %% [markdown]
# Nama  : Patricia Chandra

# %% [markdown]
# NIM : 2009106030

# %% [markdown]
# Kelas : Informatika A

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("Top 2000 Universities of the World - Sheet1.csv") ## untuk membaca dataset csv yang digunakan

# %% [markdown]
# Gunakan salah satu tipe pendekatan pada Supervised Learning.

# %%
df.head(10) ## untuk mengecek atau read data 10 pertama
# Out:
#    World Rank                            Institution         Country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
# 5           6                   Princeton University             USA
# 6           7                    Columbia University             USA
# 7           8                  University of Chicago             USA
# 8           9             University of Pennsylvania             USA
# 9          10                        Yale University             USA
#
#    National Rank Quality of Education Rank Alumni Employment Rank  \
# 0              1                         1                      1
# 1              2                         4                     12
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x.dtypes
# Out:
# World Rank                         int64
# National Rank                      int64
# Score                            float64
# Country_Algeria                    uint8
# Country_Argentina                  uint8
#                                   ...
# Research Performance Rank_995      uint8
# Research Performance Rank_996      uint8
# Research Performance Rank_997      uint8
# Research Performance Rank_998      uint8
# Research Performance Rank_999      uint8
# Length: 3697, dtype: object

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder = OrdinalEncoder()
df["Country_encoded"] = encoder.fit_transform(df[["Country"]])
df.head(12)

# %%
x.head()
# Out:
#    World Rank                            Institution         Country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    National Rank Quality of Education Rank Alumni Employment Rank  \
# 0              1                         1                      1
# 1              2                         4                     12
# 2              3                        10                      4
# 3              1                         3                     25
# 4              2                         7                     27
#
#   Quality of Faculty Rank Research Performance Rank
# 0                       1                         1
# ...

# %%
x = pd.get_dummies(x)
x.head()
# Out:
#    World Rank  National Rank  \
# 0           1              1
# 1           2              2
# 2           3              3
# 3           4              1
# 4           5              2
#
#    Institution_A.A. Kharkevich Institute for Information Transmission Problems of the Russian Academy of Sciences  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Institution_A.M. Prokhorov General Physics Institute of the Russian Academy of Sciences  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %% [markdown]
# ## Split Training

# %%
df['Score'].value_counts()
# Out:
# 65.8     29
# 66.0     28
# 65.9     27
# 66.1     27
# 66.2     27
#          ..
# 86.0      1
# 86.1      1
# 86.3      1
# 86.4      1
# 100.0     1
# Name: Score, Length: 238, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0)

# %% [markdown]
# ## Standarisasi

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
x_scaled_train = ss.fit_transform(X_train)
x_scaled_test = ss.fit_transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [101], line 1
# ----> 1 x_scaled_train = ss.fit_transform(X_train)
#       2 x_scaled_test = ss.fit_transform(X_test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
knn = KNeighborsClassifier()
knn.fit(x_scaled_train,y_train)

knn_predic = knn.predict(x_scaled_test)
accuracy_knn = accuracy_score(y_test, knn_predic)
print("Akurasi algoritma KNN dengan default paramater :", round(accuracy_knn,3))

# %% [markdown]
# ## Gunakan minimal 2 algoritma untuk membandingkan score/hasil terbaiknya.

# %%
classifier = GaussianNB()

# %%
classifier.fit(x_scaled_train,y_train)

# %%
classifier_predic = classifier.predict(x_scaled_test)
accrucary_nb = accuracy_score(y_test, classifier_predic)
print("Hasil akurasi algoritma Gaussian Naive Bayes adalah :", round(accrucary_nb,3))

# %%
algoritma = ["KNN","Gaussian Naive Bayes"]
prediksi_value = [accuracy_knn,accrucary_nb]
plt.figure(figsize=(10,10))
sns.barplot(x= algoritma, y= prediksi_value,palette='flare')
plt.title("Perbandingan Hasil Akurasi")
plt.xlabel("Akurasi (%)")
plt.ylabel("Algoritma")
plt.show()
